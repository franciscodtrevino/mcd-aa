# %% [markdown]
# Práctica 1 Análisis exploratorio
# Utilizando el dataset de los pagos de la UANL (https://github.com/ppGodel/data_mining/blob/main/csv/typed_uanl.csv) van a realizar un análisis exploratorio. Hay que crear una script donde realices lo siguiente:
#
# 1.	Identificar las entidades (que es lo que puede ser sujeto de estudio) del conjunto. agrégalo como un comentario en tu script.
# 2.	Obtener las estadísticas (descriptiva) de cada entidad (min, max, avg, std)
# 3.	Hacer agrupaciones por las entidades y sacar estadísticas de las agrupaciones.
# 4.	Crear imágenes de estas estadísticas, ya sean histogramas, graficas de pastel, etc., al menos 3 graficas diferentes, Hay que crear muchas imágenes, así que creen ciclos y recorran las agrupaciones.
# 5.	De alguna de las agrupaciones, hacer una prueba ANOVA, para ver si hay diferencias entre los elementos. recordando, hay que probar que las muestras son o no normales. sí son normales anova para la prueba y t-student para saber quién es el diferente. Si la muestra no es normal, prueba con kruskall-wallis y tukey para saber quién es el diferente.
# Realiza un reporte escrito de tus hallazgos. No quiero una descripción de que hiciste, sino de que encontraste, cosas que no sabias y supiste una vez que comenzaste a analizar los datos, cuenta que cosas guiaron tu atención para encontrar información que consideras significativa, y muestra esos hallazgos con imágenes, así que prepara tus imágenes para que alguien las vea.
# Hay que crear un repositorio de github/gitlab con 2 carpetas en la raíz del repositorio: Reportes y Practicas. En Reporte estará el reporte en formato PDF con el nombre Practica#.pdf donde # es el numero de la practica al que corresponde. En  la carpeta de prácticas por cada practica habrá una carpeta de nombre Practica# donde estará todo el código, imágenes, conjuntos de datos que usaste para la práctica.
#
# Link para pasarme tu repositorio:
# https://forms.office.com/r/YuvnZHMif0
# La fecha límite para subir el reporte y el código a git es el domingo 30 de junio.

# %%
import pandas as pd
import numpy as np

# %%
# 1. Identificar las entidades
# Entidades: Nombre (empleado), Sueldo Neto, Dependencia, Fecha, Tipo

# Cargar los datos desde el archivo CSV
df = pd.read_csv('csv/typed_uanl.csv')

# Convertir la columna 'Fecha' a tipo datetime
df['Fecha'] = pd.to_datetime(df['Fecha'])

# %%
# 2. Obtener las estadísticas descriptivas de cada entidad
estadisticas_descriptivas = df.describe(include='all')
print(estadisticas_descriptivas)

# Guardar las estadísticas descriptivas en un archivo CSV
estadisticas_descriptivas.to_csv('resultados/estadisticas_descriptivas.csv')
# Out:
#                                 Nombre    Sueldo Neto             dependencia  \
# count                           636201  636201.000000                  636201
# unique                           21034            NaN                     152
# top     JUAN ANTONIO RAMIREZ HERNANDEZ            NaN  HOSPITAL UNIVERSITARIO
# freq                                97            NaN                  105549
# first                              NaN            NaN                     NaN
# last                               NaN            NaN                     NaN
# mean                               NaN   14241.682401                     NaN
# std                                NaN    9578.442311                     NaN
# min                                NaN     175.410000                     NaN
# 25%                                NaN    8007.660000                     NaN
# 50%                                NaN   11426.500000                     NaN
# 75%                                NaN   17654.630000                     NaN
# max                                NaN  147051.590000                     NaN
#
#                       Fecha      Tipo
# count                636201    636201
# unique                   48         6
# top     2020-12-01 00:00:00  FACULTAD
# freq                  14890    274527
# first   2019-12-01 00:00:00       NaN
# last    2024-01-01 00:00:00       NaN
# mean                    NaN       NaN
# std                     NaN       NaN
# min                     NaN       NaN
# 25%                     NaN       NaN
# 50%                     NaN       NaN
# 75%                     NaN       NaN
# max                     NaN       NaN
# C:\Users\franc\AppData\Local\Temp\ipykernel_19404\182094452.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   estadisticas_descriptivas = df.describe(include='all')

# %%
# Función para obtener estadísticas descriptivas con percentiles adicionales y otros cálculos
def obtener_estadisticas_descriptivas(df, entidad):
    estadisticas = df.groupby(entidad)['Sueldo Neto'].describe()
    estadisticas['25%'] = df.groupby(entidad)['Sueldo Neto'].quantile(0.25)
    estadisticas['50%'] = df.groupby(entidad)['Sueldo Neto'].quantile(0.50)
    estadisticas['75%'] = df.groupby(entidad)['Sueldo Neto'].quantile(0.75)
    estadisticas['Rango'] = estadisticas['max'] - estadisticas['min']
    estadisticas['Varianza'] = df.groupby(entidad)['Sueldo Neto'].var()
    estadisticas['Desviación_Estándar'] = estadisticas['std']
    estadisticas['Coeficiente_de_Variación'] = estadisticas['std'] / estadisticas['mean']
    estadisticas['Número_de_Clases'] = 1 + 3.322 * np.log10(estadisticas['count'])
    estadisticas['Ancho_de_Clase'] = estadisticas['Rango'] / estadisticas['Número_de_Clases']
    return estadisticas

# Función para guardar las estadísticas en un archivo CSV
def guardar_estadisticas_csv(estadisticas, nombre_archivo):
    estadisticas.to_csv(nombre_archivo)

# Estadísticas descriptivas por dependencia
estadisticas_dependencia = obtener_estadisticas_descriptivas(df, 'dependencia')
guardar_estadisticas_csv(estadisticas_dependencia, 'resultados/estadisticas_dependencia.csv')
print("Estadísticas descriptivas por dependencia guardadas en 'estadisticas_dependencia.csv'.")

# Estadísticas descriptivas por tipo de dependencia
estadisticas_tipo = obtener_estadisticas_descriptivas(df, 'Tipo')
guardar_estadisticas_csv(estadisticas_tipo, 'resultados/estadisticas_tipo_dependencia.csv')
print("Estadísticas descriptivas por tipo de dependencia guardadas en 'estadisticas_tipo_dependencia.csv'.")

# Estadísticas descriptivas por empleado
# estadisticas_empleado = obtener_estadisticas_descriptivas(df, 'Nombre')
# guardar_estadisticas_csv(estadisticas_empleado, 'estadisticas_empleado.csv')
# print("Estadísticas descriptivas por empleado guardadas en 'estadisticas_empleado.csv'.")

# Estadísticas descriptivas por fecha
estadisticas_fecha = obtener_estadisticas_descriptivas(df, 'Fecha')
guardar_estadisticas_csv(estadisticas_fecha, 'resultados/estadisticas_fecha.csv')
print("Estadísticas descriptivas por fecha guardadas en 'estadisticas_fecha.csv'.")
# Out:
# Estadísticas descriptivas por dependencia guardadas en 'estadisticas_dependencia.csv'.
# Estadísticas descriptivas por tipo de dependencia guardadas en 'estadisticas_tipo_dependencia.csv'.
# Estadísticas descriptivas por fecha guardadas en 'estadisticas_fecha.csv'.

# %%
import pandas as pd

# Supongamos que el DataFrame df ya está cargado

# Estadísticas descriptivas para el campo "dependencia"
dependencia_stats = df['dependencia'].describe()
print("Estadísticas descriptivas para 'dependencia':")
print(dependencia_stats)

# Estadísticas descriptivas para el campo "Sueldo Neto" agrupadas por "dependencia"
sueldo_stats = df.groupby('dependencia')['Sueldo Neto'].describe().sort_values(by='mean', ascending=False)

# Renombrar las columnas para mayor claridad
sueldo_stats.rename(columns={
    'count': 'Cantidad',
    'mean': 'Promedio',
    'std': 'Desviación Estándar',
    'min': 'Mínimo',
    '25%': 'Primer Cuartil',
    '50%': 'Mediana',
    '75%': 'Tercer Cuartil',
    'max': 'Máximo'
}, inplace=True)

# print("\nEstadísticas descriptivas para 'Sueldo Neto' agrupadas por 'dependencia':")
print(sueldo_stats)

# Guardar los resultados en archivos CSV
dependencia_stats.to_csv('resultados/estadisticas_dependencia_.csv')
sueldo_stats.to_csv('resultados/estadisticas_sueldo_neto_por_dependencia.csv')

# Ordenar las estadísticas descriptivas por la dependencia con mayor cantidad de empleados de mayor a menor
sueldo_stats = sueldo_stats.sort_values(by='Cantidad', ascending=False)

# print("\nEstadísticas descriptivas para 'Sueldo Neto' agrupadas por 'dependencia' (ordenadas por cantidad de empleados):")
# print(sueldo_stats)

# Guardar los resultados en archivos CSV
sueldo_stats.to_csv('resultados/estadisticas_empleados_por_dependencia.csv')
# Out:
# Estadísticas descriptivas para 'dependencia':
# count                     636201
# unique                       152
# top       HOSPITAL UNIVERSITARIO
# freq                      105549
# Name: dependencia, dtype: object
#                                                     Cantidad      Promedio  \
# dependencia
# DIRECCION DE UNIDADES ACADEMICAS                         2.0  48706.900000
# DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA                    32.0  30192.215000
# DIRECCION RESPONSABILIDAD SOCIAL UNIVERSITARIA ...      13.0  29785.790000
# DIRECCIÓN ADMINISTRATIVA DE LA SIID                     56.0  27286.847500
# DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS         52.0  26102.060962
# ...                                                      ...           ...
# HOSPITAL UNIVERSITARIO                              105549.0   9631.383249
# JUNTA DE GOBIERNO                                      142.0   9432.126127
# DIRECCION DEL PROGRAMA DE FUTBOL AMERICANO             931.0   9385.531890
# IMPRENTA UNIVERSITARIA                                 762.0   9234.470105
# DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN       22.0   8792.027727
#
#                                                     Desviación Estándar  \
# dependencia
# DIRECCION DE UNIDADES ACADEMICAS                            7710.546900
# DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA                       24540.701895
# DIRECCION RESPONSABILIDAD SOCIAL UNIVERSITARIA ...         23277.247290
# DIRECCIÓN ADMINISTRATIVA DE LA SIID                        14274.005248
# DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS            22565.884800
# ...                                                                 ...
# HOSPITAL UNIVERSITARIO                                      4168.207964
# JUNTA DE GOBIERNO                                           2389.815714
# DIRECCION DEL PROGRAMA DE FUTBOL AMERICANO                  4804.515065
# IMPRENTA UNIVERSITARIA                                      3235.289662
# DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN           2051.254152
#
#                                                       Mínimo  Primer Cuartil  \
# dependencia
# DIRECCION DE UNIDADES ACADEMICAS                    43254.72      45980.8100
# DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA                11424.85      13195.3300
# DIRECCION RESPONSABILIDAD SOCIAL UNIVERSITARIA ...   9212.01      12552.5300
# DIRECCIÓN ADMINISTRATIVA DE LA SIID                  9464.53      12570.6400
# DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS      6704.95       7229.5025
# ...                                                      ...             ...
# HOSPITAL UNIVERSITARIO                                175.41       6946.2000
# JUNTA DE GOBIERNO                                    3702.80       7871.5950
# DIRECCION DEL PROGRAMA DE FUTBOL AMERICANO           1570.51       6415.0400
# IMPRENTA UNIVERSITARIA                               3941.72       7225.5375
# DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN    6482.20       6840.6600
#
#                                                       Mediana  Tercer Cuartil  \
# dependencia
# DIRECCION DE UNIDADES ACADEMICAS                    48706.900      51432.9900
# DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA                14917.170      62321.9325
# DIRECCION RESPONSABILIDAD SOCIAL UNIVERSITARIA ...  13245.580      55426.4100
# DIRECCIÓN ADMINISTRATIVA DE LA SIID                 23606.875      41692.4700
# DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS     11746.130      51947.9200
# ...                                                       ...             ...
# HOSPITAL UNIVERSITARIO                               8629.980      11622.8300
# JUNTA DE GOBIERNO                                    9223.750      10399.0575
# DIRECCION DEL PROGRAMA DE FUTBOL AMERICANO           8762.280      10813.2200
# IMPRENTA UNIVERSITARIA                               8483.905      11257.1925
# DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN    9172.650      10385.2300
#
#                                                       Máximo
# dependencia
# DIRECCION DE UNIDADES ACADEMICAS                    54159.08
# DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA                82985.33
# DIRECCION RESPONSABILIDAD SOCIAL UNIVERSITARIA ...  59608.67
# DIRECCIÓN ADMINISTRATIVA DE LA SIID                 57692.99
# DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS     71969.19
# ...                                                      ...
# HOSPITAL UNIVERSITARIO                              85007.77
# JUNTA DE GOBIERNO                                   18726.03
# DIRECCION DEL PROGRAMA DE FUTBOL AMERICANO          38072.02
# IMPRENTA UNIVERSITARIA                              24300.94
# DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN   13266.21
#
# [152 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Crear columnas de año y mes
df['Año'] = df['Fecha'].dt.year
df['Mes'] = df['Fecha'].dt.month

# Estadísticas generales por tipo
tipo_stats = df.groupby('Tipo')['Sueldo Neto'].describe()
tipo_stats = tipo_stats.sort_values(by='count', ascending=False)

# Estadísticas por año y mes
sueldo_por_mes = df.groupby(['Año', 'Mes'])['Sueldo Neto'].sum().unstack()
sueldo_promedio_por_mes = df.groupby(['Año', 'Mes'])['Sueldo Neto'].mean().unstack()

# Gráficos de líneas para sueldos totales por mes a lo largo de los años
plt.figure(figsize=(14, 7))
ax = sueldo_por_mes.T.plot(kind='line', title='Suma de Sueldos por Mes')
ax.set_xlabel('Mes')
ax.set_ylabel('Sueldo Total')
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.savefig('img/001-suma_sueldos_por_mes.png')
plt.close()

# Gráficos de líneas para el promedio de sueldos por mes a lo largo de los años
plt.figure(figsize=(14, 7))
ax = sueldo_promedio_por_mes.T.plot(kind='line', title='Promedio de Sueldos por Mes')
ax.set_xlabel('Mes')
ax.set_ylabel('Sueldo Promedio')
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.savefig('img/002-promedio_sueldos_por_mes.png')
plt.close()

# Top 10 tipos con mayores sueldos totales acumulados
top_10_tipos_sueldos = df.groupby('Tipo')['Sueldo Neto'].sum().nlargest(10)

# Gráficos de barras para los 10 tipos con mayores sueldos totales acumulados
plt.figure(figsize=(14, 7))
top_10_tipos_sueldos.plot(kind='bar', title='Top 10 Tipos con Mayores Sueldos Totales Acumulados')
plt.xlabel('Tipo')
plt.ylabel('Sueldo Total Acumulado')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('img/003-top_10_tipos_sueldos.png')
plt.close()


# Boxplot de sueldos por tipo
plt.figure(figsize=(14, 7))
sns.boxplot(x='Tipo', y='Sueldo Neto', data=df[df['Tipo'].isin(top_10_tipos_sueldos.index)], showfliers=False)
plt.title('Distribución de Sueldos por Tipo (Top 10)')
plt.xlabel('Tipo')
plt.ylabel('Sueldo Neto')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('img/004-distribucion_sueldos_por_tipo_top_10.png')
plt.close()

# Gráficos de líneas para los 10 tipos con mayores sueldos totales acumulados
for tipo in top_10_tipos_sueldos.index:
    df_tipo = df[df['Tipo'] == tipo].groupby('Fecha')['Sueldo Neto'].sum()
    plt.figure(figsize=(14, 7))
    ax = df_tipo.plot(kind='line', title=f'Suma de Sueldos por Fecha para {tipo}')
    ax.set_xlabel('Fecha')
    ax.set_ylabel('Sueldo Total')
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'img/005-sueldos_totales_por_fecha_{tipo}.png')
    plt.close()

# Heatmap de la matriz de correlación entre los 10 tipos con mayores sueldos totales acumulados
top_10_tipos_sueldos = df.groupby('Tipo')['Sueldo Neto'].sum().nlargest(10)
for year in df['Año'].unique():
    df_year = df[df['Año'] == year]
    pivot_table = df_year[df_year['Tipo'].isin(top_10_tipos_sueldos.index)].pivot_table(index='Fecha', columns='Tipo', values='Sueldo Neto', aggfunc='sum')
    correlation_matrix = pivot_table.corr()

    plt.figure(figsize=(14, 7))
    sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False)
    plt.title(f'Matriz de Correlación entre Tipos en {year}')
    plt.tight_layout()
    plt.savefig(f'img/006-matriz_correlacion_tipos_{year}.png')
    plt.close()

# Gráficos de líneas para sueldos totales por fecha con mínimo, máximo y promedio
sueldo_totales_por_fecha = df.groupby('Fecha')['Sueldo Neto'].agg(['sum', 'min', 'max', 'mean'])

plt.figure(figsize=(14, 7))
plt.plot(sueldo_totales_por_fecha.index, sueldo_totales_por_fecha['sum'], label='Suma')
plt.plot(sueldo_totales_por_fecha.index, sueldo_totales_por_fecha['min'], label='Mínimo')
plt.plot(sueldo_totales_por_fecha.index, sueldo_totales_por_fecha['max'], label='Máximo')
plt.plot(sueldo_totales_por_fecha.index, sueldo_totales_por_fecha['mean'], label='Promedio')
plt.title('Sueldos Totales por Fecha')
plt.xlabel('Fecha')
plt.ylabel('Sueldo')
plt.legend()
plt.grid(True)
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
plt.tight_layout()
plt.savefig('img/007-sueldo_totales_por_fecha.png')
plt.close()

# Gráfica de barras de los 5 tipos con mayores sueldos netos totales acumulados por año
top_5_tipos_sueldos = df.groupby('Tipo')['Sueldo Neto'].sum().nlargest(5)
df_top_5_anual = df[df['Tipo'].isin(top_5_tipos_sueldos.index)].groupby(['Año', 'Tipo'])['Sueldo Neto'].sum().unstack()

plt.figure(figsize=(14, 7))
df_top_5_anual.plot(kind='bar', stacked=True)
plt.title('Top 5 Tipos con Mayores Sueldos Netos Totales Acumulados por Año')
plt.xlabel('Año')
plt.ylabel('Sueldo Total Acumulado')
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))
plt.legend(title='Tipo')
plt.tight_layout()
plt.savefig('img/008-top_5_tipos_anual.png')
plt.close()

# Gráfica de pastel por año para los tipos con mayores sueldos netos totales
for year in df['Año'].unique():
    df_year = df[df['Año'] == year]
    top_10_tipos_anual = df_year.groupby('Tipo')['Sueldo Neto'].sum().nlargest(10)

    plt.figure(figsize=(14, 7))
    top_10_tipos_anual.plot(kind='pie', autopct='%1.1f%%', startangle=140)
    plt.title(f'Tipos con Mayores Sueldos Netos Totales en {year}')
    plt.ylabel('')
    plt.tight_layout()
    plt.savefig(f'img/009-tipos_mayores_sueldos_netos_{year}.png')
    plt.close()

print("Gráficos generados exitosamente.")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# Gráficos generados exitosamente.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear columna de año
df['Año'] = df['Fecha'].dt.year

def pareto_analysis(df, column, threshold=0.8):
    df = df.sort_values(by=column, ascending=False)
    df['Cumulative Sum'] = df[column].cumsum()
    df['Cumulative Percentage'] = df['Cumulative Sum'] / df[column].sum()
    pareto_df = df[df['Cumulative Percentage'] <= threshold]
    return pareto_df

# Análisis del principio de Pareto para el sueldo neto y cantidad de empleados por dependencia y por año
pareto_results_sueldo = {}
pareto_results_empleados = {}

for year in df['Año'].unique():
    df_year = df[df['Año'] == year]
    
    # Sueldo neto por dependencia
    sueldo_por_dependencia = df_year.groupby('dependencia')['Sueldo Neto'].sum().reset_index()
    pareto_sueldo = pareto_analysis(sueldo_por_dependencia, 'Sueldo Neto')
    pareto_results_sueldo[year] = pareto_sueldo
    
    # Cantidad de empleados por dependencia
    empleados_por_dependencia = df_year.groupby('dependencia')['Nombre'].nunique().reset_index()
    empleados_por_dependencia.rename(columns={'Nombre': 'Cantidad Empleados'}, inplace=True)
    pareto_empleados = pareto_analysis(empleados_por_dependencia, 'Cantidad Empleados')
    pareto_results_empleados[year] = pareto_empleados

    # Graficar resultados para el sueldo neto
    plt.figure(figsize=(12, 6))
    plt.bar(pareto_sueldo['dependencia'], pareto_sueldo['Sueldo Neto'])
    plt.title(f'Dependencias que concentran el 80% del Sueldo Neto en {year}')
    plt.xlabel('Dependencia')
    plt.ylabel('Sueldo Neto')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(f'img/010-pareto_sueldo_{year}.png')
    plt.close()

    # Graficar resultados para la cantidad de empleados
    plt.figure(figsize=(12, 6))
    plt.bar(pareto_empleados['dependencia'], pareto_empleados['Cantidad Empleados'])
    plt.title(f'Dependencias que concentran el 80% de los Empleados en {year}')
    plt.xlabel('Dependencia')
    plt.ylabel('Cantidad de Empleados')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(f'img/011-pareto_empleados_{year}.png')
    plt.close()

print("Resultados del análisis de Pareto para el sueldo neto:\n", pareto_results_sueldo)
print("Resultados del análisis de Pareto para la cantidad de empleados:\n", pareto_results_empleados)
# Out:
# Resultados del análisis de Pareto para el sueldo neto:
#  {2019:                                            dependencia  Sueldo Neto  \
# 96                              HOSPITAL UNIVERSITARIO  17910940.36
# 84                   FAC. DE ING. MECANICA Y ELECTRICA  11705189.57
# 86                                    FAC. DE MEDICINA  10195915.44
# 73                         FAC. DE CIENCIAS BIOLOGICAS   5040509.23
# 79                 FAC. DE CONTADURIA PUBLICA Y ADMON.   4618480.78
# 41                  ESC.IND.Y PREPA.TEC.ALVARO OBREG
FACULTAD DE TRABAJO SOCIAL Y DESARROLLO HUMANO                 116
# 84                            ESCUELA PREPARATORIA #25                 108
# 102                   FAC. DE MED. VETERINARIA Y ZOOT.                 106
#
#      Cumulative Sum  Cumulative Percentage
# 113            2846               0.190037
# 101            3625               0.242054
# 103            4370               0.291800
# 58             4862               0.324653
# 96             5313               0.354768
# 87             5716               0.381677
# 95             6101               0.407385
# 109            6468               0.431891
# 90             6831               0.456130
# 99             7104               0.474359
# 93             7354               0.491052
# 66             7595               0.507145
# 81             7808               0.521368
# 59             8013               0.535056
# 62             8218               0.548745
# 107            8418               0.562099
# 60             8612               0.575053
# 85             8804               0.587874
# 100            8995               0.600628
# 108            9182               0.613114
# 91             9364               0.625267
# 74             9545               0.637353
# 105            9724               0.649306
# 61             9897               0.660857
# 15            10068               0.672276
# 68            10238               0.683627
# 106           10406               0.694845
# 35            10565               0.705462
# 110           10721               0.715879
# 86            10855               0.724826
# 36            10986               0.733574
# 98            11115               0.742188
# 75            11239               0.750467
# 67            11363               0.758747
# 89            11482               0.766693
# 27            11601               0.774639
# 111           11717               0.782385
# 84            11825               0.789597
# 102           11931               0.796675  , 2022:                                            dependencia  Cantidad Empleados  \
# 111                             HOSPITAL UNIVERSITARIO                1955
# 99                   FAC. DE ING. MECANICA Y ELECTRICA                 754
# 101                                   FAC. DE MEDICINA                 728
# 56                  ESC.IND.Y PREPA.TEC.ALVARO OBREGON                 499
# 94                 FAC. DE CONTADURIA PUBLICA Y ADMON.                 470
# 85                                FAC. DE ARQUITECTURA                 380
# 93                           FAC. DE CIENCIAS QUIMICAS                 379
# 88                         FAC. DE CIENCIAS BIOLOGICAS                 370
# 107                 FACULTAD DE DERECHO Y CRIMINOLOGIA                 366
# 97                          FAC. DE FILOSOFIA Y LETRAS                 279
# 91                 FAC. DE CIENCIAS FISICO-MATEMATICAS                 265
# 64                            ESCUELA PREPARATORIA # 7                 237
# 57   ESCUELA INDUSTRIAL Y PREPARATORIA TECNICA PABL...                 212
# 79                            ESCUELA PREPARATORIA #22                 209
# 105                                 FAC. DE PSICOLOGIA                 205
# 106  FACULTAD DE CIENCIAS POLÍTICAS Y RELACIONES IN...                 204
# 89                 FAC. DE CIENCIAS DE LA COMUNICACION                 199
# 98                                  FAC. DE ING. CIVIL                 193
# 60                            ESCUELA PREPARATORIA # 3                 191
# 58                            ESCUELA PREPARATORIA # 1                 187
# 83               ESCUELA Y PREPARATORIA TECNICA MEDICA                 185
# 104                     FAC. DE ORGANIZACION DEPORTIVA                 179
# 72                            ESCUELA PREPARATORIA #15                 178
# 36                      DIRECCION DE SERVICIOS MEDICOS                 177
# 103                                FAC. DE ODONTOLOGIA                 173
# 66                            ESCUELA PREPARATORIA # 9                 172
# 59                            ESCUELA PREPARATORIA # 2                 171
# 16                       CENTRO UNIVERSITARIO DE SALUD                 170
# 108              FACULTAD DE SALUD PUBLICA Y NUTRICION                 151
# 84                                   FAC. DE AGRONOMIA                 132
# 41   DIRECCION GENERAL DE TECNOLOGÍAS Y DESARROLLO ...                 131
# 65                            ESCUELA PREPARATORIA # 8                 128
# 96                                  FAC. DE ENFERMERIA                 124
# 109     FACULTAD DE TRABAJO SOCIAL Y DESARROLLO HUMANO                 115
# 87                              FAC. DE ARTES VISUALES                 115
# 73                            ESCUELA PREPARATORIA #16                 111
# 100                   FAC. DE MED. VETERINARIA Y ZOOT.                 110
# 25                            DIRECCION DE BIBLIOTECAS                 102
# 82                            ESCUELA PREPARATORIA #25                 102
# 22                   DEPARTAMENTO ESCOLAR Y DE ARCHIVO                  96
#
#      Cumulative Sum  Cumulative Percentage
# 111            1955               0.140214
# 99             2709               0.194291
# 101            3437               0.246504
# 56             3936               0.282292
# 94             4406               0.316001
IRECCION GENERAL DE TECNOLOGÍAS Y DESARROLLO ...                 124
# 64                            ESCUELA PREPARATORIA # 2                 116
# 113              FACULTAD DE SALUD PUBLICA Y NUTRICION                 109
# 89                                   FAC. DE AGRONOMIA                 106
# 70                            ESCUELA PREPARATORIA # 8                 106
# 105                   FAC. DE MED. VETERINARIA Y ZOOT.                 105
# 101                                 FAC. DE ENFERMERIA                  96
# 25                            DIRECCION DE BIBLIOTECAS                  90
# 114     FACULTAD DE TRABAJO SOCIAL Y DESARROLLO HUMANO                  89
# 87                            ESCUELA PREPARATORIA #25                  85
# 78                            ESCUELA PREPARATORIA #16                  85
# 22                   DEPARTAMENTO ESCOLAR Y DE ARCHIVO                  85
# 28                               DIRECCION DE DEPORTES                  84
# 97                         FAC. DE CIENCIAS FORESTALES                  78
#
#      Cumulative Sum  Cumulative Percentage
# 115            2038               0.172683
# 106            2779               0.235469
# 104            3454               0.292662
# 99             3862               0.327233
# 61             4237               0.359007
# 93             4533               0.384087
# 112            4804               0.407050
# 98             5066               0.429249
# 90             5288               0.448060
# 102            5495               0.465599
# 96             5673               0.480681
# 69             5844               0.495170
# 16             6012               0.509405
# 37             6168               0.522623
# 109            6324               0.535841
# 62             6479               0.548975
# 103            6632               0.561939
# 65             6785               0.574903
# 63             6936               0.587697
# 110            7084               0.600237
# 84             7232               0.612777
# 108            7378               0.625148
# 77             7519               0.637095
# 111            7651               0.648280
# 88             7783               0.659464
# 71             7914               0.670564
# 94             8042               0.681410
# 43             8166               0.691917
# 64             8282               0.701745
# 113            8391               0.710981
# 89             8497               0.719963
# 70             8603               0.728944
# 105            8708               0.737841
# 101            8804               0.745975
# 25             8894               0.753601
# 114            8983               0.761142
# 87             9068               0.768344
# 78             9153               0.775547
# 22             9238               0.782749
# 28             9322               0.789866
# 97             9400               0.796475  }

# %%
df['Año'] = df['Fecha'].dt.year

# Función para calcular cuartiles y deciles
def calculate_quantiles(df, column, quantiles):
    return df[column].quantile(quantiles)

# Cuartiles y Deciles para el sueldo neto por año
cuartiles_results = {}
deciles_results = {}

for year in df['Año'].unique():
    df_year = df[df['Año'] == year]
    cuartiles = calculate_quantiles(df_year, 'Sueldo Neto', [0.25, 0.5, 0.75])
    deciles = calculate_quantiles(df_year, 'Sueldo Neto', [i / 10 for i in range(1, 10)])
    cuartiles_results[year] = cuartiles
    deciles_results[year] = deciles

    # Graficar cuartiles
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Sueldo Neto', data=df_year, showfliers=False)
    plt.title(f'Cuartiles del Sueldo Neto en {year}')
    plt.xlabel('Sueldo Neto')
    plt.savefig(f'img/012-cuartiles_sueldo_{year}.png')
    plt.close()

print("Resultados de Cuartiles:\n", cuartiles_results)
print("Resultados de Deciles:\n", deciles_results)
# Out:
# Resultados de Cuartiles:
#  {2019: 0.25     5355.4275
# 0.50     8182.2450
# 0.75    13347.0500
# Name: Sueldo Neto, dtype: float64, 2020: 0.25     5801.69
# 0.50     9214.06
# 0.75    14950.11
# Name: Sueldo Neto, dtype: float64, 2021: 0.25     7759.62
# 0.50    11027.34
# 0.75    17086.15
# Name: Sueldo Neto, dtype: float64, 2022: 0.25     8545.97
# 0.50    12353.32
# 0.75    18800.83
# Name: Sueldo Neto, dtype: float64, 2023: 0.25     9261.540
# 0.50    13261.730
# 0.75    19955.955
# Name: Sueldo Neto, dtype: float64, 2024: 0.25     8619.0725
# 0.50    12167.7400
# 0.75    18536.2250
# Name: Sueldo Neto, dtype: float64}
# Resultados de Deciles:
#  {2019: 0.1     4500.721
# 0.2     5161.620
# 0.3     5742.071
# 0.4     7105.642
# 0.5     8182.245
# 0.6     9526.980
# 0.7    11970.524
# 0.8    14940.698
# 0.9    21196.010
# Name: Sueldo Neto, dtype: float64, 2020: 0.1     4804.120
# 0.2     5432.390
# 0.3     6300.943
# 0.4     8007.660
# 0.5     9214.060
# 0.6    10861.780
# 0.7    13476.350
# 0.8    16909.338
# 0.9    23944.970
# Name: Sueldo Neto, dtype: float64, 2021: 0.1     6736.660
# 0.2     7378.092
# 0.3     8298.830
# 0.4     9862.170
# 0.5    11027.340
# 0.6    12853.600
# 0.7    15383.990
# 0.8    19070.960
# 0.9    26404.372
# Name: Sueldo Neto, dtype: float64, 2022: 0.1     7232.16
# 0.2     8057.87
# 0.3     9293.03
# 0.4    10868.15
# 0.5    12353.32
# 0.6    14479.12
# 0.7    17152.68
# 0.8    20926.34
# 0.9    28131.86
# Name: Sueldo Neto, dtype: float64, 2023: 0.1     7987.11
# 0.2     8687.14
# 0.3    10003.35
# 0.4    11695.85
# 0.5    13261.73
# 0.6    15415.02
# 0.7    18157.56
# 0.8    22020.48
# 0.9    29525.03
# Name: Sueldo Neto, dtype: float64, 2024: 0.1     7816.100
# 0.2     8389.372
# 0.3     9226.883
# 0.4    10649.786
# 0.5    12167.740
# 0.6    13937.080
# 0.7    16745.483
# 0.8    20736.810
# 0.9    28331.000
# Name: Sueldo Neto, dtype: float64}

# %%
# Ordenar el DataFrame por fecha
df = df.sort_values('Fecha')

# Obtener las fechas únicas ordenadas
fechas = df['Fecha'].drop_duplicates().sort_values()

# Inicializar variables
dependencias_iniciales = set(df[df['Fecha'] == fechas.iloc[0]]['dependencia'].unique())
dependencias_previas = dependencias_iniciales

# Diccionarios para almacenar dependencias nuevas, bajas y nuevas luego dadas de baja
dependencias_nuevas = {}
dependencias_bajas = {}
dependencias_nuevas_bajas = {}

# Conjunto para almacenar todas las dependencias nuevas
todas_dependencias_nuevas = set()

# Iterar sobre las fechas después del primer mes
for fecha in fechas[1:]:
    dependencias_actuales = set(df[df['Fecha'] == fecha]['dependencia'].unique())
    
    # Identificar nuevas dependencias
    nuevas = dependencias_actuales - dependencias_previas
    if nuevas:
        dependencias_nuevas[fecha.strftime('%Y-%m')] = list(nuevas)
        todas_dependencias_nuevas.update(nuevas)
    
    # Identificar dependencias que dejaron de existir
    bajas = dependencias_previas - dependencias_actuales
    if bajas:
        dependencias_bajas[fecha.strftime('%Y-%m')] = list(bajas)
    
    # Actualizar el conjunto de dependencias previas
    dependencias_previas = dependencias_actuales

# Filtrar dependencias que realmente dejaron de existir (considerando la última fecha)
dependencias_finales = set(df[df['Fecha'] == fechas.max()]['dependencia'].unique())
dependencias_bajas_reales = {k: [dep for dep in v if dep not in dependencias_finales] for k, v in dependencias_bajas.items()}

# Identificar dependencias nuevas que luego se dieron de baja
for fecha, bajas in dependencias_bajas_reales.items():
    nuevas_bajas = [dep for dep in bajas if dep in todas_dependencias_nuevas]
    if nuevas_bajas:
        dependencias_nuevas_bajas[fecha] = nuevas_bajas

# Mostrar los resultados
print("Dependencias nuevas:\n", dependencias_nuevas)
print("Dependencias que dejaron de existir:\n", dependencias_bajas_reales)
print("Dependencias nuevas que luego se dieron de baja:\n", dependencias_nuevas_bajas)
# Out:
# Dependencias nuevas:
#  {'2020-05': ['SECRETARÍA DE INNOVACIÓN Y DESARROLLO DIGITAL'], '2020-12': ['CENTRO DE VINCULACIÓN Y EMPRESAS UNIVERSITARIAS', 'DEPARTAMENTO DE ADQUISICIONES', 'DIRECCIÓN DE HUMANIDADES E HISTORIA'], '2021-01': ['UNIDAD DE TRANSPARENCIA', 'CENTRO DE DESARROLLO DE AGRONEGOCIOS', 'DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA', 'WORLD TRADE CENTER MONTEREY-UANL', 'DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN', 'DIRECCIÓN DE INNOVACIÓN Y EMPRENDIMIENTO', 'DIRECCIÓN DE INTERCAMBIO ACADÉMICO', 'DIRECCIÓN DEL SISTEMA DE ESTUDIOS DE LICENCIATURA', 'DIRECCIÓN ADMINISTRATIVA DE LA SIID', 'DIRECCIÓN DE SISTEMA DE ESTUDIOS DEL NIVEL MEDIO SUPERIOR', 'POLIDEPORTIVO TIGRES ESCOBEDO', 'DIRECCIÓN DE ADMINISTRACIÓN DE CALIDAD', 'DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS', 'DIRECCIÓN DE ESTUDIOS INCORPORADOS', 'DIRECCIÓN DE EDUCACIÓN DIGITAL', 'DIRECCIÓN DE FORMACIÓN Y DESARROLLO PROFESIONAL', 'DIRECCIÓN DE FORMACIÓN INTEGRAL AL ESTUDIANTE'], '2021-02': ['DIRECCIÓN DE INNOVACIÓN EDUCATIVA'], '2022-02': ['DIRECCION DE COMUNICACION INSTITUCIONAL Y RELACIONES PUBLICAS', 'DIRECCIÓN DE INNOVACIÓN Y DESARROLLO DE MODELOS TECNOLÓGICOS', 'DIRECCIÓN DE DESARROLLO INSTITUCIONAL ACADÉMICO', 'CENTRO DE DESARROLLO EMPRESARIAL', 'DIRECCION GENERAL DE TECNOLOGÍAS Y DESARROLLO DIGITAL', 'SECRETARIA DE RELACIONES INTERNACIONALES', 'DIRECCIÓN DE EMPRENDIMIENTO Y DESARROLLO EMPRESARIAL'], '2023-02': ['DIRECCION DE RADIO Y TELEVISION UNIVERSITARIA', 'POLIDEPORTIVO TIGRES ´ESCOBEDO´', '´CAPILLA ALFONSINA´ BIBLIOTECA UNIVERSITARIA'], '2023-04': ['CENTRO DE DESARROLLO INTEGRAL DEL ESTUDIANTE'], '2023-08': ['DIRECCIÓN DE LA UNIDAD PARA LA IGUALDAD DE GÉNERO'], '2023-09': ['DIRECCION RESPONSABILIDAD SOCIAL UNIVERSITARIA (SS)'], '2023-10': ['SECRETARÍA DE IGUALDAD E INCLUSIÓN', 'DIRECCIÓN DE EDUCACIÓN INCLUSIVA', 'DIRECCION TECNICA DE LA RECTORIA'], '2023-12': ['DIRECCION DE UNIDADES ACADEMICAS']}
# Dependencias que dejaron de existir:
#  {'2020-09': ['CENTRO DE VINCULACION SOCIAL Y EMPRESARIAL'], '2022-02': ['DIRECCIÓN DE RELACIONES INTERNACIONALES', 'DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA', 'DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN', 'WORLD TRADE CENTER MONTEREY-UANL', 'DIRECCION DE TECNOLOGIAS DE INFORMACION', 'DIRECCIÓN ADMINISTRATIVA DE LA SIID', 'DIRECCION DE COMUNICACION INSTITUCIONAL', 'DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS', 'DIRECCIÓN DE INNOVACIÓN Y EMPRENDIMIENTO', 'SECRETARÍA DE INNOVACIÓN Y DESARROLLO DIGITAL'], '2023-02': ['DIRECCIÓN GENERAL DE RADIO Y TELEVISIÓN UNIVERSITARIA', 'CAPILLA ALFONSINA BIBLIOTECA UNIVERSITARIA', 'POLIDEPORTIVO TIGRES ESCOBEDO'], '2023-10': ['GIMNASIO DE AREA MEDICA']}
# Dependencias nuevas que luego se dieron de baja:
#  {'2022-02': ['DIRECCIÓN DE INVESTIGACIÓN EDUCATIVA', 'DIRECCIÓN DE PLANEACIÓN ESTRATÉGICA EN INNOVACIÓN', 'WORLD TRADE CENTER MONTEREY-UANL', 'DIRECCIÓN ADMINISTRATIVA DE LA SIID', 'DIRECCIÓN DE DESARROLLO DE MODELOS TECNOLÓGICOS', 'DIRECCIÓN DE INNOVACIÓN Y EMPRENDIMIENTO', 'SECRETARÍA DE INNOVACIÓN Y DESARROLLO DIGITAL'], '2023-02': ['POLIDEPORTIVO TIGRES ESCOBEDO']}

# %%
df = df.sort_values('Fecha')

# Obtener las fechas únicas ordenadas
fechas = df['Fecha'].drop_duplicates().sort_values()

# Inicializar variables
empleados_iniciales = df[df['Fecha'] == fechas.iloc[0]].groupby('dependencia')['Nombre'].apply(set).to_dict()
empleados_previos = empleados_iniciales.copy()

# Diccionarios para almacenar empleados nuevos, bajas y nuevas luego dadas de baja
empleados_nuevos = {}
empleados_bajas = {}
empleados_nuevos_bajas = {}

# Conjunto para almacenar todos los empleados nuevos
todos_empleados_nuevos = {dep: set() for dep in empleados_iniciales.keys()}

# Iterar sobre las fechas después del primer mes
for fecha in fechas[1:]:
    empleados_actuales = df[df['Fecha'] == fecha].groupby('dependencia')['Nombre'].apply(set).to_dict()
    
    for dep in empleados_actuales.keys():
        if dep not in empleados_previos:
            empleados_previos[dep] = set()
            todos_empleados_nuevos[dep] = set()
        
        # Identificar nuevos empleados
        nuevas = empleados_actuales[dep] - empleados_previos[dep]
        if nuevas:
            if dep not in empleados_nuevos:
                empleados_nuevos[dep] = {}
            empleados_nuevos[dep][fecha.strftime('%Y-%m')] = list(nuevas)
            todos_empleados_nuevos[dep].update(nuevas)
        
        # Identificar empleados que dejaron de trabajar
        bajas = empleados_previos[dep] - empleados_actuales[dep]
        if bajas:
            if dep not in empleados_bajas:
                empleados_bajas[dep] = {}
            empleados_bajas[dep][fecha.strftime('%Y-%m')] = list(bajas)
    
    # Actualizar el conjunto de empleados previos incluyendo las dependencias que no estuvieron en empleados_actuales
    for dep in empleados_previos.keys():
        if dep not in empleados_actuales:
            if dep not in empleados_bajas:
                empleados_bajas[dep] = {}
            bajas = empleados_previos[dep]
            if bajas:
                empleados_bajas[dep][fecha.strftime('%Y-%m')] = list(bajas)

    # Actualizar el conjunto de empleados previos
    empleados_previos = empleados_actuales.copy()

# Filtrar empleados que realmente dejaron de trabajar (considerando la última fecha)
empleados_finales = df[df['Fecha'] == fechas.max()].groupby('dependencia')['Nombre'].apply(set).to_dict()
empleados_bajas_reales = {
    dep: {k: [emp for emp in v if dep in empleados_finales and emp not in empleados_finales[dep]] 
          for k, v in bajas.items()} 
    for dep, bajas in empleados_bajas.items()
}

# Identificar empleados nuevos que luego se dieron de baja
for dep, bajas in empleados_bajas_reales.items():
    for fecha, empleados in bajas.items():
        nuevas_bajas = [emp for emp in empleados if dep in todos_empleados_nuevos and emp in todos_empleados_nuevos[dep]]
        if nuevas_bajas:
            if dep not in empleados_nuevos_bajas:
                empleados_nuevos_bajas[dep] = {}
            empleados_nuevos_bajas[dep][fecha] = nuevas_bajas

print(f"Empleados nuevos por dependencia: {empleados_nuevos}\n\n")
# empleados_nuevos.to_csv('resultados/estadisticas_dependencia.csv')

print(f"Empleados que dejaron de trabajar por dependencia: {empleados_bajas_reales}\n\n")
# empleados_bajas_reales.to_csv('resultados/estadisticas_dependencia.csv')

print(f"Empleados nuevos por dependencia que luego se dieron de baja: {empleados_nuevos_bajas}\n\n")
# empleados_nuevos_bajas.to_csv('resultados/empleados_nuevos_bajas.csv')

# %%
from scipy.stats import shapiro, f_oneway, ttest_ind, kruskal
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
# Verificar la normalidad de las muestras por tipo
normalidad = df.groupby('Tipo')['Sueldo Neto'].apply(lambda x: shapiro(x)[1] if len(x) >= 3 else np.nan)
print("Resultados de normalidad (p-values):\n", normalidad)

# Tipos con datos suficientes para ANOVA o Kruskal-Wallis
tipos_validos = normalidad.dropna().index

# Filtrar el DataFrame para los tipos válidos
df_validos = df[df['Tipo'].isin(tipos_validos)]

# Prueba ANOVA si todas las muestras son normales
anova_resultados = f_oneway(*[df_validos[df_validos['Tipo'] == tipo]['Sueldo Neto'] for tipo in tipos_validos])
print('Resultados de ANOVA:', anova_resultados)

if anova_resultados.pvalue < 0.05:
    print("Existen diferencias significativas entre los tipos. Proceder con pruebas adicionales.")
    ttest_resultados = {}
    for i in range(len(tipos_validos)):
        for j in range(i+1, len(tipos_validos)):
            tipo1 = tipos_validos[i]
            tipo2 = tipos_validos[j]
            ttest_resultados[f'{tipo1} vs {tipo2}'] = ttest_ind(df_validos[df_validos['Tipo'] == tipo1]['Sueldo Neto'],
                                                                df_validos[df_validos['Tipo'] == tipo2]['Sueldo Neto'])
    print(ttest_resultados)
else:
    print("No existen diferencias significativas entre los tipos según ANOVA.")

# Prueba Kruskal-Wallis si alguna muestra no es normal
kruskal_resultados = kruskal(*[df_validos[df_validos['Tipo'] == tipo]['Sueldo Neto'] for tipo in tipos_validos])
print('Resultados de Kruskal-Wallis:', kruskal_resultados)

if kruskal_resultados.pvalue < 0.05:
    print("Existen diferencias significativas entre los tipos. Proceder con prueba de Tukey.")
    tukey_resultados = pairwise_tukeyhsd(df_validos['Sueldo Neto'], df_validos['Tipo'])
    print(tukey_resultados)
else:
    print("No existen diferencias significativas entre los tipos según Kruskal-Wallis.")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Resultados de normalidad (p-values):
#  Tipo
# ADMIN           0.0
# CENTRO          0.0
# FACULTAD        0.0
# HOSPITAL        0.0
# OTRO            0.0
# PREPARATORIA    0.0
# Name: Sueldo Neto, dtype: float64
# Resultados de ANOVA: F_onewayResult(statistic=9064.012908469926, pvalue=0.0)
# Existen diferencias significativas entre los tipos. Proceder con pruebas adicionales.
# {'ADMIN vs CENTRO': Ttest_indResult(statistic=7.473083595983534, pvalue=7.895872555581862e-14), 'ADMIN vs FACULTAD': Ttest_indResult(statistic=-72.89306159207187, pvalue=0.0), 'ADMIN vs HOSPITAL': Ttest_indResult(statistic=107.9006459110646, pvalue=0.0), 'ADMIN vs OTRO': Ttest_indResult(statistic=20.490034536464076, pvalue=4.333951426012629e-93), 'ADMIN vs PREPARATORIA': Ttest_indResult(statistic=-24.696954283668536, pvalue=1.7650340177498493e-134), 'CENTRO vs FACULTAD': Ttest_indResult(statistic=-52.22809599718801, pvalue=0.0), 'CENTRO vs HOSPITAL': Ttest_indResult(statistic=86.16432050811649, pvalue=0.0), 'CENTRO vs OTRO': Ttest_indResult(statistic=16.463993589177033, pvalue=1.0904347417861951e-60), 'CENTRO vs PREPARATORIA': Ttest_indResult(statistic=-26.638706630028157, pvalue=5.142129818835946e-156), 'FACULTAD vs HOSPITAL': Ttest_indResult(statistic=197.2999990716065, pvalue=0.0), 'FACULTAD vs OTRO': Ttest_indResult(statistic=50.72699597280797, pvalue=0.0), 'FACULTAD vs PREPARATORIA': Ttest_indResult(statistic=67.2801826319156, pvalue=0.0), 'HOSPITAL vs OTRO': Ttest_indResult(statistic=-42.70743176628708, pvalue=0.0), 'HOSPITAL vs PREPARATORIA': Ttest_indResult(statistic=-168.96334089034784, pvalue=0.0), 'OTRO vs PREPARATORIA': Ttest_indResult(statistic=-37.872806938203986, pvalue=0.0)}
# Resultados de Kruskal-Wallis: KruskalResult(statistic=43614.84651539198, pvalue=0.0)
# Existen diferencias significativas entre los tipos. Proceder con prueba de Tukey.
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#  group1     group2     meandiff  p-adj   lower      upper    reject
# -------------------------------------------------------------------
#    ADMIN       CENTRO  -518.2844   0.0  -709.9208   -326.648   True
#    ADMIN     FACULTAD  3211.3688   0.0  3103.8192  3318.9183   True
#    ADMIN     HOSPITAL -3672.8157   0.0 -3797.8074 -3547.8241   True
#    ADMIN         OTRO -1890.4612   0.0 -2147.5405 -1633.3819   True
#    ADMIN PREPARATORIA   976.8796   0.0   858.8224  1094.9367   True
#   CENTRO     FACULTAD  3729.6532   0.0  3555.8009  3903.5054   True
#   CENTRO     HOSPITAL -3154.5313   0.0 -3339.6816 -2969.3811   True
#   CENTRO         OTRO -1372.1768   0.0  -1663.291 -1081.0626   True
#   CENTRO PREPARATORIA   1495.164   0.0  1314.6226  1675.7053   True
# FACULTAD     HOSPITAL -6884.1845   0.0  -6979.699 -6788.6699   True
# FACULTAD         OTRO -5101.8299   0.0 -5345.9403 -4857.7195   True
# FACULTAD PREPARATORIA -2234.4892   0.0 -2320.7307 -2148.2477   True
# HOSPITAL         OTRO  1782.3545   0.0  1530.0732  2034.6359   True
# HOSPITAL PREPARATORIA  4649.6953   0.0   4542.487  4756.9035   True
#     OTRO PREPARATORIA  2867.3407   0.0  2618.4221  3116.2593   True
# -------------------------------------------------------------------

# %%
import pandas as pd
from scipy.stats import shapiro, f_oneway, ttest_ind, kruskal, norm, lognorm, expon
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
import seaborn as sns

# Supongamos que el DataFrame df ya está cargado
# df = pd.read_csv('csv/typed_itam.csv')
# df['Fecha'] = pd.to_datetime(df['Fecha'])

# Crear columnas de año y mes
df['Año'] = df['Fecha'].dt.year
df['Mes'] = df['Fecha'].dt.month

# Filtrar los tipos con suficientes datos
tipos_validos = df['Tipo'].unique()

# Función para ajustar distribuciones
def fit_distributions(data):
    dist_names = ['norm', 'lognorm', 'expon']
    dist_results = {}
    for dist_name in dist_names:
        dist = getattr(__import__('scipy.stats', fromlist=[dist_name]), dist_name)
        params = dist.fit(data)
        dist_results[dist_name] = params
    return dist_results

# Pruebas ANOVA y Kruskal-Wallis por mes
resultados_anova = {}
resultados_kruskal = {}
distribuciones = {}

for year in df['Año'].unique():
    for month in df['Mes'].unique():
        df_month = df[(df['Año'] == year) & (df['Mes'] == month)]
        
        if df_month.empty:
            continue
        
        normalidad = df_month.groupby('Tipo')['Sueldo Neto'].apply(lambda x: shapiro(x)[1] if len(x) >= 3 else np.nan)
        tipos_validos_mes = normalidad.dropna().index
        df_validos_mes = df_month[df_month['Tipo'].isin(tipos_validos_mes)]
        
        if df_validos_mes.empty:
            continue
        
        # Prueba ANOVA si todas las muestras son normales
        if all(normalidad.dropna() > 0.05):
            anova_resultados = f_oneway(*[df_validos_mes[df_validos_mes['Tipo'] == tipo]['Sueldo Neto'] for tipo in tipos_validos_mes])
            resultados_anova[(year, month)] = anova_resultados
            if anova_resultados.pvalue < 0.05:
                ttest_resultados = {}
                for i in range(len(tipos_validos_mes)):
                    for j in range(i+1, len(tipos_validos_mes)):
                        tipo1 = tipos_validos_mes[i]
                        tipo2 = tipos_validos_mes[j]
                        ttest_resultados[f'{tipo1} vs {tipo2}'] = ttest_ind(df_validos_mes[df_validos_mes['Tipo'] == tipo1]['Sueldo Neto'],
                                                                            df_validos_mes[df_validos_mes['Tipo'] == tipo2]['Sueldo Neto'])
                print(f"Resultados de t-test para {year}-{month}:\n", ttest_resultados)
        else:
            kruskal_resultados = kruskal(*[df_validos_mes[df_validos_mes['Tipo'] == tipo]['Sueldo Neto'] for tipo in tipos_validos_mes])
            resultados_kruskal[(year, month)] = kruskal_resultados
            if kruskal_resultados.pvalue < 0.05:
                tukey_resultados = pairwise_tukeyhsd(df_validos_mes['Sueldo Neto'], df_validos_mes['Tipo'])
                print(f"Resultados de Tukey para {year}-{month}:\n", tukey_resultados)
                
                distribuciones[(year, month)] = {}
                for tipo in tipos_validos_mes:
                    data = df_validos_mes[df_validos_mes['Tipo'] == tipo]['Sueldo Neto']
                    distribuciones[(year, month)][tipo] = fit_distributions(data)
                print(f"Distribuciones ajustadas para {year}-{month}:\n", distribuciones[(year, month)])

print("Resultados de ANOVA:\n", resultados_anova)
print("Resultados de Kruskal-Wallis:\n", resultados_kruskal)
print("Distribuciones ajustadas:\n", distribuciones)

# %%
import pandas as pd
from tabulate import tabulate
from typing import Tuple, List

import matplotlib.pyplot as plt
# import statsmodels.api as sm
from statsmodels.formula.api import ols



import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, f_oneway, ttest_ind, kruskal
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd



def print_tabulate(df: pd.DataFrame):
    print(tabulate(df, headers=df.columns, tablefmt='orgtbl'))


def categorize(name:str)->str:
    if 'PREPARATORIA' in name or 'PREPA.' in name:
        return 'PREPARATORIA'
    if 'FACULTAD' in name or 'FAC.' in name:
        return 'FACULTAD'
    if 'HOSPITAL' in name:
        return 'HOSPITAL'
    if 'CENTRO' in name or 'CTRO.' in name or 'C.' in name or 'INVESTIGAC' in name :
        return 'CENTRO'
    if 'SECRETARÍA' in name or 'SECRETARIA' in name or 'SRIA.' in name or 'DIRECCIÓN' in name or 'DIRECCION' in name or \
       'DEPARTAMENTO' in name or 'DEPTO.' in name or 'CONTRALORIA' in name or 'AUDITORIA' in name or 'TESORERIA' in name \
       or 'ESCOLAR' in name or 'ABOGACÍA' in name  or 'JUNTA' in name  or 'RECTORIA' in name  or 'IMAGEN' in name :
        return 'ADMIN'
    return 'OTRO'

def transform_into_typed_df(raw_df: pd.DataFrame)->pd.DataFrame:
    raw_df["Fecha"] = pd.to_datetime(raw_df["anio"].map(str)+ "-" + raw_df["mes"].map(str), format="%Y-%m")
    raw_df = raw_df.drop(['anio', 'mes'], axis=1)
    raw_df["Tipo"] = raw_df["dependencia"].map(categorize)
    return raw_df



def normalize_data(file_name:str) -> str:
    df_complete = pd.read_csv(file_name)
    df_complete["Fecha"] = pd.to_datetime(df_complete["anio"].map(str)+ "-" + df_complete["mes"].map(str), format="%Y-%m")
    df_complete = df_complete.drop(['anio', 'mes'], axis=1)
    df_complete["Tipo"] = df_complete["dependencia"].map(categorize)
    df_complete.to_csv("csv/typed_uanl.csv", index=False)
    return "csv/typed_uanl.csv"

def analysis_dependencia(file_name:str)->None:
    df_complete = pd.read_csv(file_name)
    df_complete["Fecha"] = pd.to_datetime(df_complete["Fecha"], format="%Y-%m-%d")
    df_complete["anio"] = df_complete["Fecha"].dt.year
    # df_by_dep = df_complete.groupby(["dependencia", "anio"]).agg({'Sueldo Neto': ['sum', 'count']})
    # print_tabulate(df_by_dep.head())
    df_by_dep = df_complete.groupby(["dependencia", "Fecha"]).agg({'Sueldo Neto': ['sum', 'count', 'mean', 'min', 'max']})
    df_by_dep = df_by_dep.reset_index()
    print_tabulate(df_by_dep.head())
    df_by_dep.to_csv("csv/uanl_dependencia_mes.csv")


def create_boxplot_by_type(file_name:str, column: str, agg_fn= pd.DataFrame.sum):
    df_complete = pd.read_csv(file_name)
    df_by_type = df_complete.groupby([column,"Fecha"])[["Sueldo Neto"]].aggregate(agg_fn)# .count()
    df_by_type.boxplot(by = column, figsize=(27,18))
    plt.xticks(rotation=90)
    plt.savefig(f"img2/boxplot_{column}.png")
    plt.close()


def plot_by_dep(df: pd.DataFrame, dep:str)->None:
    df[df["dependencia"] == dep].plot(y =["Sueldo Neto"])
    plt.savefig(f"img2/lt_{dep}.png")
    df[df["dependencia"] == dep].boxplot(by ='dependencia')
    plt.savefig(f"img2/bplt_{dep}.png")


def create_plot_por_dependencia(file_name:str):
    df_complete = pd.read_csv(file_name)
    df_by_dep = df_complete.groupby(["dependencia", "Fecha"])[["Sueldo Neto"]].aggregate(pd.DataFrame.mean)
    df_by_dep.reset_index(inplace=True)
    df_by_dep.set_index("Fecha", inplace=True)

    for dep in set(df_by_dep["dependencia"]):
       plot_by_dep(df_by_dep, dep)
    df_aux = df_complete.groupby(["Fecha","dependencia"])[['Sueldo Neto']].mean().unstack()
    df_aux.plot(y = 'Sueldo Neto', legend=False, figsize=(32,18))
    plt.xticks(rotation=90)
    plt.savefig("img2/foo.png")
    plt.close()

def anova(df_aux: pd.DataFrame, str_ols: str):
    # shaphiro-wills
    # Levenes or barletts
    modl = ols(str_ols, data=df_aux).fit()
    anova_df = sm.stats.anova_lm(modl, typ=2)
    if anova_df["PR(>F)"][0] < 0.005:
        print("hay diferencias")
        print(anova_df)
        # Prueba tukey
        # imprimir los resultados
    else:
        print("No hay diferencias")

def anova_1(file_name: str):
    df_complete = pd.read_csv(file_name)
    df_by_type = df_complete.groupby(["Tipo", "Fecha"])[["Sueldo Neto"]].aggregate(pd.DataFrame.sum)
    df_by_type.reset_index(inplace=True)
    df_by_type.set_index("Fecha", inplace=True)
    df_by_type.reset_index(inplace=True)
    df_aux = df_by_type.rename(columns={"Sueldo Neto": "GastoSalarios"}).drop(['Fecha'], axis=1)
    print(df_aux.head())
    anova(df_aux, "GastoSalarios ~ Tipo")

def analysis(file_name: str) -> None:
    df_complete = pd.read_csv(file_name)
    # print_tabulate(df_complete[["dependencia","Tipo"]].drop_duplicates().head(150))
    df_by_dep = df_complete.groupby(["dependencia", "Fecha"])[["Sueldo Neto"]].aggregate(pd.DataFrame.sum)

    # df_by_dep_by_anio = df_by_dep.groupby(["dependencia","anio"]).aggregate(pd.DataFrame.sum).sort_values(by=["dependencia", "anio"], ascending=True)
    df_by_dep.reset_index(inplace=True)
    df_by_dep.set_index("Fecha", inplace=True)
    # print_tabulate(df_by_dep.head(5))

    for dep in set(df_by_dep["dependencia"]):
        plot_by_dep(df_by_dep, dep)
    
    df_by_type = df_complete.groupby(["Tipo", "Fecha"])[["Sueldo Neto"]].aggregate(pd.DataFrame.sum)
    df_by_type.boxplot(by='Tipo', figsize=(18,9))
    plt.xticks(rotation=90)
    plt.savefig("img2/boxplot_tipo.png")
    plt.close()

    aux = df_complete.groupby(["Tipo"])[["Sueldo Neto"]].aggregate(pd.DataFrame.sum)
    aux.reset_index(inplace=True)
    df_by_type.reset_index(inplace=True)
    df_aux = df_by_type.rename(columns={"Sueldo Neto": "GastoSalarios"}).drop(['Fecha'], axis=1)
    print(df_aux.head())

    # Prueba ANOVA
    modl = ols("GastoSalarios ~ Tipo", data=df_aux).fit()
    anova_df = sm.stats.anova_lm(modl, typ=2)
    if anova_df["PR(>F)"][0] < 0.005:
        print("Hay diferencias")
        print(anova_df)
        # Prueba Tukey
        tukey_resultados = pairwise_tukeyhsd(df_aux['GastoSalarios'], df_aux['Tipo'])
        print(tukey_resultados)
    else:
        print("No hay diferencias")



def create_typed_df(filename:str)-> pd.DataFrame:
    df_complete = pd.read_csv(filename)
    raw_df = transform_into_typed_df(df_complete)
    print_tabulate(raw_df.head(50))
    raw_df.to_csv("csv/typed_uanl.csv", index=False)
    return raw_df

def show_type_of_department():
    df_complete = pd.read_csv("csv/typed_uanl.csv")
    print_tabulate(df_complete[["dependencia","Tipo"]].\
                   drop_duplicates().head(150))

def show_data_by_dependency_and_date():
    df_complete = pd.read_csv("csv/typed_uanl.csv")
    df_by_dep = df_complete.groupby(["dependencia", "Fecha"])[["Sueldo Neto"]].aggregate(pd.DataFrame.sum)
    df_by_dep.reset_index(inplace=True)
    df_by_dep.set_index("Fecha", inplace=True)
    print_tabulate(df_by_dep[df_by_dep["dependencia"]== "FAC. DE CIENCIAS FISICO-MATEMATICAS"].head(50))


def show_data_by_type_and_date():
    df_complete = pd.read_csv("csv/typed_uanl.csv")
    df_by_type = df_complete.groupby(["Tipo", "Fecha"])[["Sueldo Neto"]].aggregate(pd.DataFrame.sum)
    df_by_type.reset_index(inplace=True)
    df_by_type.set_index("Fecha", inplace=True)
    print_tabulate(df_by_type.head(150))


def show_salary_and_count_by_type_and_date():
    df_complete = pd.read_csv("csv/typed_uanl.csv")
    df_by_type = df_complete.groupby(["Tipo", "Fecha"]).agg({'Sueldo Neto': ['sum', 'count', 'mean', 'min']})
    df_by_type.reset_index(inplace=True)
    df_by_type.columns = ['Tipo', 'Fecha', 'Total_sueldos', 'Conteo_Empleado', 'Promedio_sueldo', 'Salario_Maximo']
    df_by_type.set_index("Fecha", inplace=True)
    print_tabulate(df_by_type.head(150))

def show_salary_and_count_by_dependency_and_date():
    df_complete = pd.read_csv("csv/typed_uanl.csv")
    df_by_type = df_complete.groupby(["dependencia", "Fecha"]).agg({'Sueldo Neto': ['sum', 'count', 'mean', 'max']})
    df_by_type.reset_index(inplace=True)
    df_by_type.columns = ['Tipo', 'Fecha', 'Total_sueldos', 'Conteo_Empleado', 'Promedio_sueldo', 'Salario_Maximo']
    df_by_type.set_index("Fecha", inplace=True)
    print_tabulate(df_by_type)


if __name__ == "__main__":
    # analysis_dependencia("csv/typed_uanl.csv")
    # create_typed_df("csv/uanl.csv")
    # show_data_by_dependency_and_date()
    # show_data_by_type_and_date()
    # show_salary_and_count_by_type_and_date()
    # show_salary_and_count_by_dependency_and_date()
    
    #### analysis("csv/typed_uanl.csv")
    
    # create_boxplot_by_type("csv/typed_uanl.csv", 'dependencia', pd.DataFrame.mean)#"Tipo")
    create_plot_por_dependencia("csv/typed_uanl.csv")
    # anova_1("csv/typed_uanl.csv")
